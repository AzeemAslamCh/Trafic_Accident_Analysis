# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import plotly.express as px

# %%
pio.renderers.default = 'iframe_connected'

# %%
data=pd.read_csv('traffic-accidents-annual-.csv')
data
# Out:
#    *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                     NaN       Year  Total number of accidents
# 1                Pakistan    2008-09                       9496
# 2                Pakistan    2009-10                       9747
# 3                Pakistan    2010-11                       9723
# 4                Pakistan    2011-12                       9140
# ..                    ...        ...                        ...
# 58              Islamabad    2014-15                        216
# 59              Islamabad    2015-16                        244
# 60              Islamabad    2016-17                        226
# 61              Islamabad    2017-18                        259
# 62              Islamabad    2018-19                        238
#
#          Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# 1              4145                 5351       4907      11037
# 2              4378                 5369       5280      11173
# 3              4280                 5443       5271      11383
# 4              3966                 5174       4758      10145
# ..              ...                  ...        ...        ...
# 58              107                  109        118        182
# 59              120                  124        140        209
# 60              127                   99        129        124
# 61              157                  102        167        162
# 62              127                  111        136        134
#
#                            Unnamed: 7
# 0   Total number of vehicles involved
# 1                               10322
# 2                               10496
# 3                               10822
# 4                                9986
# ..                                ...
# 58                                217
# 59                                244
# 60                                216
# 61                                259
# 62                                239
#
# [63 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   *- Islamabad Included.  62 non-null     object
#  1   Unnamed: 1              63 non-null     object
#  2   Unnamed: 2              63 non-null     object
#  3   Unnamed: 3              63 non-null     object
#  4   Unnamed: 4              63 non-null     object
#  5   Unnamed: 5              63 non-null     object
#  6   Unnamed: 6              63 non-null     object
#  7   Unnamed: 7              63 non-null     object
# dtypes: object(8)
# memory usage: 4.1+ KB

# %%
data.head()
# Out:
#   *- Islamabad Included. Unnamed: 1                 Unnamed: 2  \
# 0                    NaN       Year  Total number of accidents
# 1               Pakistan    2008-09                       9496
# 2               Pakistan    2009-10                       9747
# 3               Pakistan    2010-11                       9723
# 4               Pakistan    2011-12                       9140
#
#         Unnamed: 3           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  Fatal Accidents  Non-Fatal Accidents     Killed    Injured
# 1             4145                 5351       4907      11037
# 2             4378                 5369       5280      11173
# 3             4280                 5443       5271      11383
# 4             3966                 5174       4758      10145
#
#                           Unnamed: 7
# 0  Total number of vehicles involved
# 1                              10322
# 2                              10496
# 3                              10822
# 4                               9986

# %%
data.columns
# Out:
# Index(['*- Islamabad Included.', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
data.rename(columns={'*- Islamabad Included.':'Place','Unnamed: 1':'Year','Unnamed: 2':'Total_accidents','Unnamed: 3':'Fatal_Accident',
                    'Unnamed: 4':'Non-Fatal_Accidents','Unnamed: 5':'Killed','Unnamed: 6':'Injured','Unnamed: 7':'Total_vehicles_involved'},inplace=True)

# %%
data
# Out:
#         Place     Year            Total_accidents   Fatal_Accident  \
# 0         NaN     Year  Total number of accidents  Fatal Accidents
# 1    Pakistan  2008-09                       9496             4145
# 2    Pakistan  2009-10                       9747             4378
# 3    Pakistan  2010-11                       9723             4280
# 4    Pakistan  2011-12                       9140             3966
# ..        ...      ...                        ...              ...
# 58  Islamabad  2014-15                        216              107
# 59  Islamabad  2015-16                        244              120
# 60  Islamabad  2016-17                        226              127
# 61  Islamabad  2017-18                        259              157
# 62  Islamabad  2018-19                        238              127
#
#     Non-Fatal_Accidents  Killed  Injured            Total_vehicles_involved
# 0   Non-Fatal Accidents  Killed  Injured  Total number of vehicles involved
# 1                  5351    4907    11037                              10322
# 2                  5369    5280    11173                              10496
# 3                  5443    5271    11383                              10822
# 4                  5174    4758    10145                               9986
# ..                  ...     ...      ...                                ...
# 58                  109     118      182                                217
# 59                  124     140      209                                244
# 60                   99     129      124                                216
# 61                  102     167      162                                259
# 62                  111     136      134                                239
#
# [63 rows x 8 columns]

# %% [markdown]
# - Drop First Row

# %%
data=data.iloc[1:]
data
# Out:
#         Place        Year Total_accidents Fatal_Accident Non-Fatal_Accidents  \
# 1    Pakistan     2008-09            9496           4145                5351
# 2    Pakistan     2009-10            9747           4378                5369
# 3    Pakistan     2010-11            9723           4280                5443
# 4    Pakistan     2011-12            9140           3966                5174
# 5    Pakistan  2012-13 *             8988           3884                5104
# ..        ...         ...             ...            ...                 ...
# 58  Islamabad     2014-15             216            107                 109
# 59  Islamabad     2015-16             244            120                 124
# 60  Islamabad     2016-17             226            127                  99
# 61  Islamabad     2017-18             259            157                 102
# 62  Islamabad     2018-19             238            127                 111
#
#    Killed Injured Total_vehicles_involved
# 1    4907   11037                   10322
# 2    5280   11173                   10496
# 3    5271   11383                   10822
# 4    4758   10145                    9986
# 5    4719    9710                    9876
# ..    ...     ...                     ...
# 58    118     182                     217
# 59    140     209                     244
# 60    129     124                     216
# 61    167     162                     259
# 62    136     134                     239
#
# [62 rows x 8 columns]

# %%
data.head(10)
# Out:
#        Place        Year Total_accidents Fatal_Accident Non-Fatal_Accidents  \
# 1   Pakistan     2008-09            9496           4145                5351
# 2   Pakistan     2009-10            9747           4378                5369
# 3   Pakistan     2010-11            9723           4280                5443
# 4   Pakistan     2011-12            9140           3966                5174
# 5   Pakistan  2012-13 *             8988           3884                5104
# 6   Pakistan    2013-14*            8359           3500                4859
# 7   Pakistan    2014-15*            7865           3214                4651
# 8   Pakistan    2015-16*            9100           3591                5509
# 9   Pakistan    2016-17*            9582           4036                5546
# 10  Pakistan     2017-18           11121           4829                6292
#
#    Killed Injured Total_vehicles_involved
# 1    4907   11037                   10322
# 2    5280   11173                   10496
# 3    5271   11383                   10822
# 4    4758   10145                    9986
# 5    4719    9710                    9876
# 6    4348    9777                    9423
# 7    3954    9661                    8949
# 8    4448   11544                   10636
# 9    5047   12696                   11317
# 10   5948   14489                   13134

# %% [markdown]
# - Some Years written with (*) so it should be replace

# %%
data['Year']=data['Year'].replace("2012-13 * ","2012-13")
data['Year']=data['Year'].replace("2013-14*","2013-14")
data['Year']=data['Year'].replace("2014-15*","2014-15")
data['Year']=data['Year'].replace("2015-16*","2015-16")
data['Year']=data['Year'].replace("2016-17*","2016-17")
# Out:
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/2037518482.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/2037518482.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/2037518482.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/2037518482.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/2037518482.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head(10)
# Out:
#        Place     Year Total_accidents Fatal_Accident Non-Fatal_Accidents  \
# 1   Pakistan  2008-09            9496           4145                5351
# 2   Pakistan  2009-10            9747           4378                5369
# 3   Pakistan  2010-11            9723           4280                5443
# 4   Pakistan  2011-12            9140           3966                5174
# 5   Pakistan  2012-13            8988           3884                5104
# 6   Pakistan  2013-14            8359           3500                4859
# 7   Pakistan  2014-15            7865           3214                4651
# 8   Pakistan  2015-16            9100           3591                5509
# 9   Pakistan  2016-17            9582           4036                5546
# 10  Pakistan  2017-18           11121           4829                6292
#
#    Killed Injured Total_vehicles_involved
# 1    4907   11037                   10322
# 2    5280   11173                   10496
# 3    5271   11383                   10822
# 4    4758   10145                    9986
# 5    4719    9710                    9876
# 6    4348    9777                    9423
# 7    3954    9661                    8949
# 8    4448   11544                   10636
# 9    5047   12696                   11317
# 10   5948   14489                   13134

# %% [markdown]
# - (-)sign includes in year columns it should be split

# %%
data['Year']=data['Year'].str.split("-").str[0]
data=data.explode('Year',ignore_index=True)
# Out:
# C:\Users\azeem\AppData\Local\Temp/ipykernel_10464/3796079608.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head()
# Out:
#       Place  Year  Total_accidents  Fatal_Accident  Non-Fatal_Accidents  \
# 0  Pakistan  2008             9496            4145                 5351
# 1  Pakistan  2009             9747            4378                 5369
# 2  Pakistan  2010             9723            4280                 5443
# 3  Pakistan  2011             9140            3966                 5174
# 4  Pakistan  2012             8988            3884                 5104
#
#    Killed  Injured  Total_vehicles_involved
# 0    4907    11037                    10322
# 1    5280    11173                    10496
# 2    5271    11383                    10822
# 3    4758    10145                     9986
# 4    4719     9710                     9876

# %% [markdown]
# - Change data types of Columns

# %%
data=data.astype({'Place':str,'Year':int,'Total_accidents':int,'Fatal_Accident':int,'Non-Fatal_Accidents':int,
                 'Killed':int,'Injured':int,'Total_vehicles_involved':int})
data
# Out:
#         Place  Year  Total_accidents  Fatal_Accident  Non-Fatal_Accidents  \
# 0    Pakistan  2008             9496            4145                 5351
# 1    Pakistan  2009             9747            4378                 5369
# 2    Pakistan  2010             9723            4280                 5443
# 3    Pakistan  2011             9140            3966                 5174
# 4    Pakistan  2012             8988            3884                 5104
# ..        ...   ...              ...             ...                  ...
# 57  Islamabad  2014              216             107                  109
# 58  Islamabad  2015              244             120                  124
# 59  Islamabad  2016              226             127                   99
# 60  Islamabad  2017              259             157                  102
# 61  Islamabad  2018              238             127                  111
#
#     Killed  Injured  Total_vehicles_involved
# 0     4907    11037                    10322
# 1     5280    11173                    10496
# 2     5271    11383                    10822
# 3     4758    10145                     9986
# 4     4719     9710                     9876
# ..     ...      ...                      ...
# 57     118      182                      217
# 58     140      209                      244
# 59     129      124                      216
# 60     167      162                      259
# 61     136      134                      239
#
# [62 rows x 8 columns]

# %%
# sel=data[{'Year','Total_accidents'}].loc[(data.Place=='Pakistan')]
# graph=px.bar(sel,x='Year',y='Total_accidents',color='Year',text='Total_accidents',title='Total Traffic Accident in Pakistan')
# graph.update_traces(texttemplate='%{text}',textposition='outside')
# graph.show()

# %%
fa=data[{'Year','Fatal_Accident','Place'}].loc[(data.Place=='Pakistan')]
graph=px.bar(fa,x='Year',y='Fatal_Accident',color='Year',text='Fatal_Accident',title='Total Fatal Accident in Pakistan')
graph.update_traces(texttemplate='%{text}',textposition='outside')
graph.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pa=data[{'Year','Total_accidents'}].loc[(data.Place=='Punjab')]
graph=px.scatter(pa,x='Year',y='Total_accidents',color='Year',size='Total_accidents',title='Total Accidents In Punjab')
graph.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
Place=['Sindh','Punjab',"Balochistan","Khyber Pakhtunkhwa"]
ratio=data[{'Place','Total_accidents'}].loc[data['Place'].isin(Place)]

fig=px.pie(ratio,values='Total_accidents',names='Place',width=900,height=900,color='Place',color_discrete_map={'Punjab':'red',
                                 'Sindh':'orange',
                                 'Balochistan':'royalblue',
                                 'Khyber Pakhtunkhwa':'green'},
                                 title='Ratio Of Traffic Accident in Provinces ')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="920px"
#     height="920"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
Place=['Sindh','Punjab',"Balochistan","Khyber Pakhtunkhwa"]
dr=data[{'Place','Killed'}].loc[data['Place'].isin(Place)]

fig=px.pie(dr,values='Killed',names='Place',width=950,height=900,color='Place',color_discrete_map={'Punjab':'lightcyan',
                                 'Sindh':'cyan',
                                 'Balochistan':'royalblue',
                                 'Khyber Pakhtunkhwa':'darkblue'},
                                 title='Ratio Of People Died Through Accident in Provinces ')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="970px"
#     height="920"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
